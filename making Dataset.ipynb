# %% [markdown]
# ## downloading GOOGLE images using python

# %%
from imutils import paths

# %% [markdown]
# ## Import Libraries
#
# by the help of requests library we can download the images

# %%
import requests

# %%
import argparse
import cv2
import os

# %% [markdown]
# To open the file having the urls of the images.

# %%
#open('F:\Downloads\urls.txt')
f= open("F:/Downloads/urls.txt").read()

# %%
rows=f.strip().split("\n")
total=0

# %% [markdown]
# ## Now download the images

# %%
for url in rows:
    try:
        # try to download the image
        r = requests.get(url, timeout=60)
 
        # save the image to disk
        p = os.path.sep.join(["F:/Downloads/images/", "{}.jpg".format(
        str(total).zfill(8))])
        f = open(p, "wb")
        f.write(r.content)
        f.close()
 
        # update the counter
        print("[INFO] downloaded: {}".format(p))
        total += 1
 
    # handle if any exceptions are thrown during the download process
    except:
        print("[INFO] error downloading {}...skipping".format(p))
# Out:
# [INFO] downloaded: F:/Downloads/images/\00000000.jpg
# [INFO] downloaded: F:/Downloads/images/\00000001.jpg
# [INFO] downloaded: F:/Downloads/images/\00000002.jpg
# [INFO] downloaded: F:/Downloads/images/\00000003.jpg
# [INFO] downloaded: F:/Downloads/images/\00000004.jpg
# [INFO] downloaded: F:/Downloads/images/\00000005.jpg
# [INFO] downloaded: F:/Downloads/images/\00000006.jpg
# [INFO] downloaded: F:/Downloads/images/\00000007.jpg
# [INFO] downloaded: F:/Downloads/images/\00000008.jpg
# [INFO] downloaded: F:/Downloads/images/\00000009.jpg
# [INFO] downloaded: F:/Downloads/images/\00000010.jpg
# [INFO] downloaded: F:/Downloads/images/\00000011.jpg
# [INFO] downloaded: F:/Downloads/images/\00000012.jpg
# [INFO] downloaded: F:/Downloads/images/\00000013.jpg
# [INFO] downloaded: F:/Downloads/images/\00000014.jpg
# [INFO] downloaded: F:/Downloads/images/\00000015.jpg
# [INFO] downloaded: F:/Downloads/images/\00000016.jpg
# [INFO] downloaded: F:/Downloads/images/\00000017.jpg
# ...

# %% [markdown]
# Now loop through all files just downloaded and try to open them with OpenCV. If the file can’t be opened with OpenCV, delete it and move on.

# %%
for imagePath in paths.list_images("F:/Downloads/images/"):
    # initialize if the image should be deleted or not
    delete = False
 
    # try to load the image
    try:
        image = cv2.imread(imagePath)
 
        # if the image is `None` then we could not properly load it
        # from disk, so delete it
        if image is None:
            delete = True
 
    # if OpenCV cannot load the image then the image is likely
    # corrupt so we should delete it
    except:
        print("Except")
        delete = True
 
    # check to see if the image should be deleted
    if delete:
        print("[INFO] deleting {}".format(imagePath))
        os.remove(imagePath)
# Out:
# [INFO] deleting F:/Downloads/images/00000046.jpg
# [INFO] deleting F:/Downloads/images/00000079.jpg
# [INFO] deleting F:/Downloads/images/00000108.jpg
# [INFO] deleting F:/Downloads/images/00000123.jpg
# [INFO] deleting F:/Downloads/images/00000132.jpg
# [INFO] deleting F:/Downloads/images/00000133.jpg
# [INFO] deleting F:/Downloads/images/00000145.jpg
# [INFO] deleting F:/Downloads/images/00000224.jpg
# [INFO] deleting F:/Downloads/images/00000235.jpg
# [INFO] deleting F:/Downloads/images/00000255.jpg
# [INFO] deleting F:/Downloads/images/00000257.jpg
# [INFO] deleting F:/Downloads/images/00000276.jpg
# [INFO] deleting F:/Downloads/images/00000303.jpg
# [INFO] deleting F:/Downloads/images/00000313.jpg
# [INFO] deleting F:/Downloads/images/00000335.jpg
# [INFO] deleting F:/Downloads/images/00000352.jpg
# [INFO] deleting F:/Downloads/images/00000367.jpg
# [INFO] deleting F:/Downloads/images/00000378.jpg
# [INFO] deleting F:/Downloads/images/00000409.jpg
# ...
